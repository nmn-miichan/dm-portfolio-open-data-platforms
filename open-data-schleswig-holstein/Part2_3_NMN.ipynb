# %% [markdown]
# ## Examine the RDF file for police stations ("Polizeidienststellen")
# ### 1. Use SPARQL to query all police stations located in "Kiel"

# %%
from rdflib.plugins.sparql import prepareQuery
from rdflib import Graph
import json

# %%
g = Graph()
g.parse("polizeidienststellen-2024-01-28.rdf")

query_kiel = """
PREFIX schema: <http://schema.org/>

SELECT ?station ?name ?latitude ?longitude ?postalcode ?streetaddress ?telephone ?faxnumber ?email  
WHERE {
    # ?station  a schema:PoliceStation ;
                schema:name ?name ;
                schema:location ?location ;
                schema:address ?address ;
                schema:telephone ?telephone ;
                schema:faxNumber ?faxnumber ;
                schema:email ?email .
    # ?location schema:geo ?geo .
    # ?geo      schema:latitude ?latitude ;
              schema:longitude ?longitude .
    # ?address    schema:addressLocality "Kiel" ;
                schema:postalCode ?postalcode ;
                schema:streetAddress ?streetaddress .
}
"""

results_kiel = g.query(query_kiel)

results_kiel_list = [
    {
        "station": str(row.station),
        "name": str(row.name),
        "latitude": float(row.latitude),
        "longitude": float(row.longitude),
        "postalcode": int(row.postalcode),
        "streetaddress": str(row.streetaddress),
        "telephone": str(row.telephone),
        "faxnumber": str(row.faxnumber),
        "email": str(row.email)
    }
    for row in results_kiel
]

results_kiel_json = json.dumps(results_kiel_list, indent=4, ensure_ascii=False)

print(results_kiel_json)
# Out:
# [
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9092250",
#         "name": "3. Polizeirevier Kiel",
#         "latitude": 54.31637046286201,
#         "longitude": 10.123243886338098,
#         "postalcode": 24114,
#         "streetaddress": "Von-der-Tann-Straße 34",
#         "telephone": "+49 431 160-1310",
#         "faxnumber": "+49 431 160-1319",
#         "email": "Kiel.Prev03@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9092804",
#         "name": "4. Polizeirevier Kiel",
#         "latitude": 54.31080664144833,
#         "longitude": 10.139483723164112,
#         "postalcode": 24143,
#         "streetaddress": "Werftstraße 217",
#         "telephone": "+49 431 160-1410",
#         "faxnumber": "+49 431 160-1419",
#         "email": "Kiel.Prev04@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9093224",
#         "name": "Kriminalpolizeistelle Kiel",
#         "latitude": 54.32691369616649,
#         "longitude": 10.130254903962124,
#         "postalcode": 24103,
#         "streetaddress": "Blumenstraße 2 - 4",
#         "telephone": "+49 431 160-3322",
#         "faxnumber": "+49 431 160-3119",
#         "email": "Kiel.KPSt@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9093825",
#         "name": "Landeskriminalamt",
#         "latitude": 54.33198962849225,
#         "longitude": 10.10685814821424,
#         "postalcode": 24116,
#         "streetaddress": "Mühlenweg 166",
#         "telephone": "+49 431 160-0",
#         "faxnumber": "+49 431 160-4118",
#         "email": "Kiel.LKA111@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9094379",
#         "name": "Polizei-Bezirksrevier Kiel",
#         "latitude": 54.33198962849225,
#         "longitude": 10.10685814821424,
#         "postalcode": 24116,
#         "streetaddress": "Mühlenweg 166",
#         "telephone": "+49 431 160-1502",
#         "faxnumber": "+49 431 160-1519",
#         "email": "Kiel.PBR@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9095329",
#         "name": "Polizeidirektion Kiel",
#         "latitude": 54.32601335467837,
#         "longitude": 10.129403242773417,
#         "postalcode": 24103,
#         "streetaddress": "Gartenstraße 7",
#         "telephone": "+49 431 160-0",
#         "faxnumber": "+49 431 160-2029",
#         "email": "Kiel.PD@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9095973",
#         "name": "Polizeistation Dietrichsdorf",
#         "latitude": 54.33247954783718,
#         "longitude": 10.190166878747547,
#         "postalcode": 24149,
#         "streetaddress": "Ivensring 27",
#         "telephone": "+49 431 160-1452",
#         "faxnumber": "+49 431 160-1469",
#         "email": "Dietrichsdorf.PSt@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9096144",
#         "name": "Polizeistation Friedrichsort",
#         "latitude": 54.39553964578254,
#         "longitude": 10.16984390188149,
#         "postalcode": 24159,
#         "streetaddress": "Fritz-Reuter-Straße 94",
#         "telephone": "+49 431 160-1172",
#         "faxnumber": "+49 431 160-1189",
#         "email": "Friedrichsort.PSt@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9096384",
#         "name": "Polizeistation Hassee",
#         "latitude": 54.30132477160224,
#         "longitude": 10.113217306521896,
#         "postalcode": 24113,
#         "streetaddress": "Rendsburger Landstraße 206",
#         "telephone": "+49 431 160-1352",
#         "faxnumber": "+49 431 160-1369",
#         "email": "Hassee.PSt@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9096529",
#         "name": "Polizeistation Holtenau",
#         "latitude": 54.36960018162906,
#         "longitude": 10.144359829955109,
#         "postalcode": 24159,
#         "streetaddress": "Kanalstraße 46",
#         "telephone": "+49 431 361165",
#         "faxnumber": "+49 431 3645487",
#         "email": "Holtenau.PSt@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9096845",
#         "name": "Polizeistation Mettenhof",
#         "latitude": 54.32570820182378,
#         "longitude": 10.05738787873588,
#         "postalcode": 24114,
#         "streetaddress": "Skandinaviendamm 251",
#         "telephone": "+49 431 160-1372",
#         "faxnumber": "+49 431 160-1399",
#         "email": "Mettenhof.PSt@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9097369",
#         "name": "Polizeistation Schilksee",
#         "latitude": 54.416825644678724,
#         "longitude": 10.171755530923365,
#         "postalcode": 24159,
#         "streetaddress": "Langenfelde 123 c",
#         "telephone": "+49 431 372363",
#         "faxnumber": "+49 431 3003992",
#         "email": "Schilksee.PSt@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9097594",
#         "name": "Polizeistation Suchsdorf",
#         "latitude": 54.35755288444286,
#         "longitude": 10.082715665751778,
#         "postalcode": 24107,
#         "streetaddress": "Eckernförder Straße 425",
#         "telephone": "+49 431 1601190",
#         "faxnumber": "+49 431 1601196",
#         "email": "Suchsdorf.PSt@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9097975",
#         "name": "Polizeistation Wik",
#         "latitude": 54.35623420519531,
#         "longitude": 10.132555826673949,
#         "postalcode": 24106,
#         "streetaddress": "Wiker Straße 53",
#         "telephone": "+49 431 160-1152",
#         "faxnumber": "+49 431 160-1169",
#         "email": "Wik.PSt@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9098027",
#         "name": "Landespolizeiamt",
#         "latitude": 54.33198962849225,
#         "longitude": 10.10685814821424,
#         "postalcode": 24116,
#         "streetaddress": "Mühlenweg 166",
#         "telephone": "+49 431 160-0",
#         "faxnumber": "+49 431 160-5123",
#         "email": "STK.Kiel.LPA@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9098070",
#         "name": "Bezirkskriminalinspektion Kiel",
#         "latitude": 54.32691369616649,
#         "longitude": 10.130254903962124,
#         "postalcode": 24103,
#         "streetaddress": "Blumenstraße 2 - 4",
#         "telephone": "+49 431 160-0",
#         "faxnumber": "+49 431 160-3209",
#         "email": "Kiel.BKI@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9098798",
#         "name": "Wasserschutzpolizeirevier Kiel",
#         "latitude": 54.33565987792664,
#         "longitude": 10.154906701557179,
#         "postalcode": 24105,
#         "streetaddress": "Arwed-Emminghaus-Weg 11",
#         "telephone": "+49 431 160-1660",
#         "faxnumber": "+49 431 160-1609",
#         "email": "kiel.wsprv@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9099244",
#         "name": "1. Polizeirevier Kiel",
#         "latitude": 54.33895513652535,
#         "longitude": 10.148349188926597,
#         "postalcode": 24105,
#         "streetaddress": "Düppelstraße 23",
#         "telephone": "+49 431 160-1110",
#         "faxnumber": "+49 431 160-1119",
#         "email": "Kiel.Prev01@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9099726",
#         "name": "2. Polizeirevier Kiel",
#         "latitude": 54.32422960752982,
#         "longitude": 10.139839841353696,
#         "postalcode": 24103,
#         "streetaddress": "Falckstraße 4",
#         "telephone": "+49 431 160-1210",
#         "faxnumber": "+49 431 160-1219",
#         "email": "Kiel.Prev02@polizei.landsh.de"
#     },
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9118626",
#         "name": "Landespolizeiamt - Dezernat 13",
#         "latitude": 54.33198962849225,
#         "longitude": 10.10685814821424,
#         "postalcode": 24116,
#         "streetaddress": "Mühlenweg 166",
#         "telephone": "+49 431 160-0",
#         "faxnumber": "+49 431 160-60109",
#         "email": "kiel.lpa13@polizei.landsh.de"
#     }
# ]

# %% [markdown]
# ### 2. Provide another example query of your choice
# => Query all police stations near Fachhochschule Kiel (with the same zip code 24149)

# %%
query_24149 = """
PREFIX schema: <http://schema.org/>

SELECT ?station ?name ?latitude ?longitude ?postalcode ?streetaddress ?telephone ?faxnumber ?email  
WHERE {
    # ?station  a schema:PoliceStation ;
                schema:name ?name ;
                schema:location ?location ;
                schema:address ?address ;
                schema:telephone ?telephone ;
                schema:faxNumber ?faxnumber ;
                schema:email ?email .
    # ?location schema:geo ?geo .
    # ?geo      schema:latitude ?latitude ;
              schema:longitude ?longitude .
    # ?address    schema:addressLocality ?addresslocality ;
                schema:postalCode "24149" ;
                schema:streetAddress ?streetaddress .
}
"""

results_24149 = g.query(query_24149)

result_24149_list = [
    {
        "station": str(row.station),
        "name": str(row.name),
        "latitude": float(row.latitude),
        "longitude": float(row.longitude),
        "streetaddress": str(row.streetaddress),
        "telephone": str(row.telephone),
        "faxnumber": str(row.faxnumber),
        "email": str(row.email)
    }
    for row in results_24149
]

results_24149_json = json.dumps(result_24149_list, indent=4, ensure_ascii=False)

print(results_24149_json)
# Out:
# [
#     {
#         "station": "https://zufish.schleswig-holstein.de/portaldeeplink?tsa_oe_id=9095973",
#         "name": "Polizeistation Dietrichsdorf",
#         "latitude": 54.33247954783718,
#         "longitude": 10.190166878747547,
#         "streetaddress": "Ivensring 27",
#         "telephone": "+49 431 160-1452",
#         "faxnumber": "+49 431 160-1469",
#         "email": "Dietrichsdorf.PSt@polizei.landsh.de"
#     }
# ]
